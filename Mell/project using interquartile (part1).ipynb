# %% [markdown]
# # Imports

# %%
#this one use pure quantile to filter data
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data
df = pd.read_csv('Ames_Housing_Data.csv')

# %% [markdown]
# # Explainatory data analysis

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
df.describe()
# Out:
#                 PID  MS SubClass  Lot Frontage       Lot Area  Overall Qual  \
# count  2.930000e+03  2930.000000   2440.000000    2930.000000   2930.000000
# mean   7.144645e+08    57.387372     69.224590   10147.921843      6.094881
# std    1.887308e+08    42.638025     23.365335    7880.017759      1.411026
# min    5.263011e+08    20.000000     21.000000    1300.000000      1.000000
# 25%    5.284770e+08    20.000000     58.000000    7440.250000      5.000000
# 50%    5.354536e+08    50.000000     68.000000    9436.500000      6.000000
# 75%    9.071811e+08    70.000000     80.000000   11555.250000      7.000000
# max    1.007100e+09   190.000000    313.000000  215245.000000     10.000000
#
#        Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# count   2930.000000  2930.000000     2930.000000   2907.000000   2929.000000
# mean       5.563140  1971.356314     1984.266553    101.896801    442.629566
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#df.corr()['SalePrice'].sort_values()
df = pd.read_csv('Ames_Housing_Data.csv')

a =df.corr()['SalePrice'].sort_values(ascending =False).head(15)

print(a)
#print(df.info())
# Out:
# SalePrice         1.000000
# Overall Qual      0.799262
# Gr Liv Area       0.706780
# Garage Cars       0.647877
# Garage Area       0.640401
# Total Bsmt SF     0.632280
# 1st Flr SF        0.621676
# Year Built        0.558426
# Full Bath         0.545604
# Year Remod/Add    0.532974
# Garage Yr Blt     0.526965
# Mas Vnr Area      0.508285
# TotRms AbvGrd     0.495474
# Fireplaces        0.474558
# BsmtFin SF 1      0.432914
# Name: SalePrice, dtype: float64

# %% [markdown]
# # SalePrice

# %%
####################################################################

''' this section is for overall SalePrice'''

####################################################################
# Out:
# ' this section is for overall SalePrice'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['SalePrice'],kde=True)
plt.show()

# %%
print(df['SalePrice'].skew())
df['SalePrice'].describe() 
#more than one shows right skewed
# Out:
# 1.7435000757376466
# count      2930.000000
# mean     180796.060068
# std       79886.692357
# min       12789.000000
# 25%      129500.000000
# 50%      160000.000000
# 75%      213500.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#dont run this 2 cell belows
#this to put ceiling and floor to the values

# %%
print(df['SalePrice'].quantile(0.05))
print(df['SalePrice'].quantile(0.99))
# Out:
# 87500.0
# 456666.3700000001

# %%
#set floor and ceiling values                                                                                                                                                                                                                                                                                                                      
df["SalePrice"] = np.where(df["SalePrice"] <12789.0, 12789.0,df['SalePrice'])
df["SalePrice"] = np.where(df["SalePrice"] >755000.0, 755000.0,df['SalePrice'])
print(df['SalePrice'].skew())
# Out:
# 1.7435000757376466

# %% [markdown]
# # Overall qual

# %%
####################################################################

''' this section is for overall qual'''

####################################################################
# Out:
# ' this section is for overall qual'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Overall Qual'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Overall Qual', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Overall Qual"],data=df)
plt.show()

# %%
x= df['Overall Qual'].quantile(0.50)
print(x)
# Out:
# 6.0

# %%
df['Overall Qual'] = np.where(df['Overall Qual'] < 2,x,df['Overall Qual'])
print(df['Overall Qual'].skew())
df.describe()['Overall Qual']
# Out:
# 0.24728379394087968
# count    2930.000000
# mean        6.101706
# std         1.398396
# min         2.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: Overall Qual, dtype: float64

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Overall Qual'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Overall Qual', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Overall Qual"],data=df)
plt.show()

# %%
#comparison with SalePrice
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='Overall Qual',y='SalePrice')
plt.show()

# %% [markdown]
# # Gr Liv Area

# %%
####################################################################

''' this section is for Gr Liv Area'''

####################################################################
# Out:
# ' this section is for Gr Liv Area'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Gr Liv Area'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Gr Liv Area"],data=df)
plt.show()

# %%
#i dont think area can use quantile
#it limit the area available
#play with 4 decimal quantile to preserve more data
x =df['Gr Liv Area'].quantile(0.50)
y =df['Gr Liv Area'].quantile(0.9985)
print(x) 
print(y)
# Out:
# 1442.0
# 4120.824000000161

# %%
 df[(df['Gr Liv Area']>y)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 1760  528320050           60        RL         160.0     15623   Pave   NaN
# 1767  528351010           60        RL         104.0     21535   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 1498       IR3          Bnk    AllPub  ...       480      Gd    NaN
# 1760       IR1          Lvl    AllPub  ...       555      Ex  MnPrv
# 1767       IR1          Lvl    AllPub  ...         0     NaN    NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN    NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# ...

# %%
df[(df['Gr Liv Area']>y)].index
# Out:
# Int64Index([1498, 1760, 1767, 2180, 2181], dtype='int64')

# %%
df = df.drop(df[(df['Gr Liv Area']>y)].index)
#df['Gr Liv Area'] = np.where(df['Gr Liv Area'] >y, x, df['Gr Liv Area'])
#putting median causes unrealistic value for some data
print(df['Gr Liv Area'].skew())
df.describe()['Gr Liv Area']
# Out:
# 0.8788794722662926
# count    2925.000000
# mean     1493.978803
# std       486.273646
# min       334.000000
# 25%      1126.000000
# 50%      1441.000000
# 75%      1740.000000
# max      3820.000000
# Name: Gr Liv Area, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
#spike sbb move the price of outlier to middle
#but does this make sense? isnt there a smthing not right here
#probbly drop is better in this situation
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Gr Liv Area"],data=df)
plt.show()

# %%
#comparison with SalePrice

'''
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='Gr Liv Area',y='SalePrice')
plt.show()
#probably need to use diff graph..this looks like Seeeeeeeeeeeeeeee
'''
# Out:
# "\nplt.figure(figsize=(12,8))\nsns.boxplot(data=df, x='Gr Liv Area',y='SalePrice')\nplt.show()\n#probably need to use diff graph..this looks like Seeeeeeeeeeeeeeee\n"

# %% [markdown]
# # Garage Cars

# %%
####################################################################

''' this section is for  Garage Cars'''

####################################################################
# Out:
# ' this section is for  Garage Cars'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Garage Cars'],kde=True)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(x='Garage Cars',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Cars', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Cars"],data=df)
plt.show()

# %%
x = df['Garage Cars'].quantile(0.50)
print(x)
# Out:
# 2.0

# %%
 df[(df['Garage Cars']>3)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 246   906204230           60        RL          87.0     12361   Pave   NaN
# 669   535402330           90        RL          91.0     11643   Pave   NaN
# 716   902326030           70        RM          65.0     11700   Pave  Pave
# 746   903236040           30        RM          50.0      8635   Pave   NaN
# 815   906230010           90        RL           NaN     11855   Pave   NaN
# 816   906230020           90        RL           NaN      7939   Pave   NaN
# 817   906230030           90        RL           NaN      7976   Pave   NaN
# 1027  527357180           60        RL           NaN     12511   Pave   NaN
# 1059  528118090           60        RL          96.0     12539   Pave   NaN
# 1258  535380140           50        RL          60.0     10836   Pave  Grvl
# 1588  923202005           90        RM          97.0      8940   Pave   NaN
# ...

# %%
#after modeling , i disable this option 
#df['Garage Cars'] = np.where(df['Garage Cars'] >3, x, df['Garage Cars'])
#print(df['Garage Cars'].skew())
#df.describe()['Garage Cars']

# %%
plt.figure(figsize=(14,5))
sns.scatterplot(x='Garage Cars',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Cars', ylabel='SalePrice'>

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Cars"],data=df)
plt.show()

# %%
#comparison with SalePrice
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='Garage Cars',y='SalePrice')
plt.show()

# %% [markdown]
# # Garage Area

# %%
####################################################################

''' this section is for Garage Area'''

####################################################################
# Out:
# ' this section is for Garage Area'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Garage Area'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Area',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Area"],data=df)
plt.show()

# %%
x = df['Garage Area'].quantile(0.5)
y = df['Garage Area'].quantile(0.998)
print(x) 
print(y)
# Out:
# 480.0
# 1233.618

# %%
 df[(df['Garage Area']>y)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 426   528108020           20        RL          98.0     12704   Pave   NaN
# 1027  527357180           60        RL           NaN     12511   Pave   NaN
# 1258  535380140           50        RL          60.0     10836   Pave  Grvl
# 1425  906412010           20        RL          91.0     11778   Pave   NaN
# 1557  911226010           30   C (all)         120.0     18000   Grvl   NaN
# 2282  923205025          190        RL           NaN     32463   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence  \
# 426        Reg          Lvl    AllPub  ...         0     NaN    NaN
# 1027       IR1          Lvl    AllPub  ...         0     NaN  MnPrv
# 1258       Reg          Lvl    AllPub  ...         0     NaN   GdWo
# 1425       Reg          Lvl    AllPub  ...         0     NaN    NaN
# 1557       Reg          Low    AllPub  ...         0     NaN    NaN
# ...

# %%
df = df.drop(df[(df['Garage Area']>y)].index)

# %%
'''
df['Garage Area'] = np.where(df['Garage Area'] >y,x, df['Garage Area'])
print(df['Garage Area'].skew())
df.describe()

'''

df = df.drop(df[(df['Garage Area']>y)].index)
#df['Gr Liv Area'] = np.where(df['Gr Liv Area'] >y, x, df['Gr Liv Area'])
#putting median causes unrealistic value for some data
print(df['Garage Area'].skew())
df.describe()['Garage Area']
# Out:
# 0.09433379619583732
# count    2918.000000
# mean      470.063057
# std       210.200792
# min         0.000000
# 25%       320.000000
# 50%       479.500000
# 75%       576.000000
# max      1231.000000
# Name: Garage Area, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Area',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Area"],data=df)
plt.show()

# %%
#comparison with SalePrice
'''
plt.figure(figsize=(12,8))
sns.boxplot(data=df, x='Garage Area',y='SalePrice')
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(12,8))\nsns.boxplot(data=df, x='Garage Area',y='SalePrice')\nplt.show()\n"

# %% [markdown]
# # Total Bsmt SF

# %%
####################################################################

''' this section is for Total Bsmt SF'''

####################################################################
# Out:
# ' this section is for Total Bsmt SF'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Total Bsmt SF'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Total Bsmt SF',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Total Bsmt SF"],data=df)
plt.show()

# %%
x = df['Total Bsmt SF'].quantile(0.028)
y = df['Total Bsmt SF'].quantile(0.50)
z= df['Total Bsmt SF'].quantile(0.99)
print(x)
print(y)
print(z)
# Out:
# 184.49200000000027
# 988.5
# 2136.0

# %%
 df[(df['Total Bsmt SF']<x)]['Total Bsmt SF']
# Out:
# 83      0.0
# 154     0.0
# 206     0.0
# 243     0.0
# 273     0.0
#        ...
# 2739    0.0
# 2744    0.0
# 2879    0.0
# 2892    0.0
# 2903    0.0
# Name: Total Bsmt SF, Length: 82, dtype: float64

# %%
 df[(df['Total Bsmt SF']>z)]['Total Bsmt SF']
# Out:
# 44      2330.0
# 46      2846.0
# 349     2208.0
# 366     2216.0
# 379     2524.0
# 423     3094.0
# 432     2630.0
# 444     3206.0
# 447     2392.0
# 448     2452.0
# 456     2492.0
# 457     2200.0
# 513     2458.0
# 802     2158.0
# 959     2190.0
# 1056    2418.0
# 1063    2535.0
# 1613    2223.0
# 1614    2217.0
# 1637    2660.0
# 1641    2220.0
# 1695    2552.0
# 1697    2153.0
# 1701    2320.0
# 1763    2633.0
# 1772    3200.0
# 1860    2461.0
# 2099    2140.0
# 2592    2171.0
# Name: Total Bsmt SF, dtype: float64

# %%
'''
df['Total Bsmt SF'] = np.where(df['Total Bsmt SF'] >z,y, df['Total Bsmt SF'])
df['Total Bsmt SF'] = np.where(df['Total Bsmt SF'] <x,y, df['Total Bsmt SF'])
df.describe()['Total Bsmt SF']}
'''
# Out:
# "\ndf['Total Bsmt SF'] = np.where(df['Total Bsmt SF'] >z,y, df['Total Bsmt SF'])\ndf['Total Bsmt SF'] = np.where(df['Total Bsmt SF'] <x,y, df['Total Bsmt SF'])\ndf.describe()['Total Bsmt SF']}\n"

# %%
df[(df['Total Bsmt SF']<x)].index
# Out:
# Int64Index([  83,  154,  206,  243,  273,  275,  290,  551,  649,  674,  676,
#              678,  708,  780,  786,  787,  794,  806,  807,  809,  810,  811,
#              812,  814,  884,  887,  896,  898,  945,  952,  970, 1204, 1219,
#             1251, 1254, 1259, 1266, 1268, 1325, 1343, 1374, 1497, 1500, 1501,
#             1503, 1506, 1553, 1554, 1568, 1817, 1879, 1886, 1898, 1901, 1968,
#             2003, 2004, 2070, 2081, 2088, 2176, 2184, 2212, 2241, 2278, 2337,
#             2487, 2616, 2621, 2622, 2624, 2625, 2626, 2679, 2700, 2702, 2706,
#             2739, 2744, 2879, 2892, 2903],
#            dtype='int64')

# %%
df[(df['Total Bsmt SF']>z)].index
# Out:
# Int64Index([  44,   46,  349,  366,  379,  423,  432,  444,  447,  448,  456,
#              457,  513,  802,  959, 1056, 1063, 1613, 1614, 1637, 1641, 1695,
#             1697, 1701, 1763, 1772, 1860, 2099, 2592],
#            dtype='int64')

# %%
df = df.drop(df[(df['Total Bsmt SF']<x)].index)
df = df.drop(df[(df['Total Bsmt SF']>z)].index)

#putting median causes unrealistic value for some data
print(df['Total Bsmt SF'].skew())
df.describe()['Total Bsmt SF']
# Out:
# 0.5078313851066006
# count    2807.000000
# mean     1061.806555
# std       360.943965
# min       190.000000
# 25%       808.000000
# 50%       996.000000
# 75%      1297.500000
# max      2136.000000
# Name: Total Bsmt SF, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Total Bsmt SF',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Total Bsmt SF"],data=df)
plt.show()

# %% [markdown]
# # 1st Flr SF

# %%
####################################################################

''' this section is for 1st Flr SF'''

####################################################################
# Out:
# ' this section is for 1st Flr SF'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['1st Flr SF'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='1st Flr SF',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["1st Flr SF"],data=df)
plt.show()

# %%
x = df['1st Flr SF'].quantile(0.50)
y= df['1st Flr SF'].quantile(0.995)
print(x) 
print(y)
# Out:
# 1078.0
# 2121.965

# %%
 df[(df['1st Flr SF']>y)]['1st Flr SF']
# Out:
# 136     2207
# 937     2365
# 1572    2898
# 1689    2122
# 1833    2129
# 1854    2362
# 2077    2422
# 2078    2158
# 2222    2259
# 2229    2515
# 2230    2726
# 2258    2279
# 2498    2151
# 2525    2156
# 2561    2136
# Name: 1st Flr SF, dtype: int64

# %%
'''
df['1st Flr SF'] = np.where(df['1st Flr SF'] >y,x, df['1st Flr SF'])
df.describe()

#changing it to median causes this problem
#eat more than 1500++ data
'''

df[(df['Total Bsmt SF']>y)].index
# Out:
# Int64Index([956, 2561], dtype='int64')

# %%
df = df.drop(df[(df['1st Flr SF']>y)].index)

#putting median causes unrealistic value for some data
print(df['1st Flr SF'].skew())
df.describe()['1st Flr SF']
# Out:
# 0.5198215414061685
# count    2793.000000
# mean     1136.255639
# std       343.218061
# min       407.000000
# 25%       872.000000
# 50%      1075.000000
# 75%      1367.000000
# max      2121.000000
# Name: 1st Flr SF, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='1st Flr SF',y='SalePrice',data=df)
plt.show()

# %%
#check for outlier
plt.figure(figsize=(12,8))
sns.boxplot(x=df["1st Flr SF"],data=df)
plt.show()

# %%
####################################################################

''' this section is for overall Year Built'''

####################################################################
# Out:
# ' this section is for overall Year Built'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Year Built'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Built',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Year Built"],data=df)
plt.show()

# %%
x = df['Year Built'].quantile(0.50)
y = df['Year Built'].quantile(0.0025)
print(x) 
print(y)
# Out:
# 1974.0
# 1881.96

# %%
 df[(df['Year Built']<y)]['Year Built']
# Out:
# 215     1875
# 716     1880
# 1306    1880
# 1318    1872
# 1995    1880
# 1997    1879
# 2647    1880
# Name: Year Built, dtype: int64

# %%
'''
df['Year Built'] = np.where(df['Year Built'] <y,x, df['Year Built'])
df.describe()['Year Built']

'''

df[(df['Year Built']<y)].index
# Out:
# Int64Index([215, 716, 1306, 1318, 1995, 1997, 2647], dtype='int64')

# %%
df = df.drop(df[(df['Year Built']<y)].index)

#putting median causes unrealistic value for some data
print(df['Year Built'].skew())
df.describe()['Year Built']
# Out:
# -0.5916569960483992
# count    2786.000000
# mean     1971.769203
# std        30.095316
# min      1882.000000
# 25%      1954.000000
# 50%      1974.000000
# 75%      2001.000000
# max      2010.000000
# Name: Year Built, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Built',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Year Built"],data=df)
plt.show()

# %% [markdown]
# # Full Bath

# %%
####################################################################

''' this section is for Full Bath'''

####################################################################
# Out:
# ' this section is for Full Bath'

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Full Bath'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Full Bath',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Full Bath"],data=df)
plt.show()

# %%
x = df['Full Bath'].quantile(0.50)
y = df['Full Bath'].quantile(0.99)
print(x) 
print(y)
# Out:
# 2.0
# 3.0

# %%
 df[(df['Full Bath']>y)]['Full Bath']
# Out:
# 336    4
# 815    4
# 816    4
# 817    4
# Name: Full Bath, dtype: int64

# %%
#after modeling also consider disbling this function
#df = df.drop(df[(df['Full Bath']>y)].index)

#putting median causes unrealistic value for some data
print(df['Full Bath'].skew())
df.describe()['Full Bath']
# Out:
# 0.16881496975241966
# count    2786.000000
# mean        1.558507
# std         0.550163
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Full Bath, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Full Bath',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Full Bath"],data=df)
plt.show()

# %% [markdown]
# # Year Remod/Add

# %%
####################################################################

''' this section is for Year Remod/Add '''

####################################################################
# Out:
# ' this section is for Year Remod/Add '

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Year Remod/Add'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Remod/Add',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Year Remod/Add"],data=df)
plt.show()

# %% [markdown]
# # Garage Yr Blt

# %%
####################################################################

''' this section is for Garage Yr Blt '''

####################################################################
# Out:
# ' this section is for Garage Yr Blt '

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Garage Yr Blt'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Yr Blt',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Yr Blt"],data=df)
plt.show()

# %%
x = df['Garage Yr Blt'].quantile(0.001)
y = df['Garage Yr Blt'].quantile(0.50)
z = df['Garage Yr Blt'].quantile(0.999)
print(x) 
print(y) 
print(z)
# Out:
# 1900.0
# 1980.0
# 2010.0

# %%
 df[(df['Garage Yr Blt']<x)]['Garage Yr Blt']
# Out:
# 307    1896.0
# Name: Garage Yr Blt, dtype: float64

# %%
 df[(df['Garage Yr Blt']>z)]['Garage Yr Blt']
# Out:
# 2260    2207.0
# Name: Garage Yr Blt, dtype: float64

# %%
df = df.drop(df[(df['Garage Yr Blt']>z)].index)
df = df.drop(df[(df['Garage Yr Blt']<x)].index)
#putting median causes unrealistic value for some data
print(df['Garage Yr Blt'].skew())
df.describe()['Garage Yr Blt']
# Out:
# -0.6774283298638563
# count    2641.000000
# mean     1978.286255
# std        25.148119
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: Garage Yr Blt, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Yr Blt',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Garage Yr Blt"],data=df)
plt.show()

# %% [markdown]
# # Mas Vnr Area

# %%
####################################################################

''' this section is for Mas Vnr Area  '''

####################################################################
# Out:
# ' this section is for Mas Vnr Area  '

# %%
plt.figure(figsize=(20,10),dpi=90)
sns.displot(df['Mas Vnr Area'],kde=True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Mas Vnr Area',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Mas Vnr Area"],data=df)
plt.show()

# %%
y = df['Mas Vnr Area'].quantile(0.50)
z = df['Mas Vnr Area'].quantile(0.95)
print(y)
print(z)
# Out:
# 0.0
# 447.60000000000036

# %%
 df[(df['Mas Vnr Area']>z)]['Mas Vnr Area']
# Out:
# 15      603.0
# 20      480.0
# 29      504.0
# 30      492.0
# 38      450.0
#         ...
# 2764    621.0
# 2868    459.0
# 2883    473.0
# 2894    653.0
# 2899    630.0
# Name: Mas Vnr Area, Length: 139, dtype: float64

# %%
df = df.drop(df[(df['Mas Vnr Area']>z)].index)

#putting median causes unrealistic value for some data
print(df['Mas Vnr Area'].skew())
df.describe()['Mas Vnr Area']
# Out:
# 1.4782626721403989
# count    2624.000000
# mean       70.741997
# std       112.768428
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       130.000000
# max       444.000000
# Name: Mas Vnr Area, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Mas Vnr Area',y='SalePrice',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x=df["Mas Vnr Area"],data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2645 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2645 non-null   int64
#  1   MS SubClass      2645 non-null   int64
#  2   MS Zoning        2645 non-null   object
#  3   Lot Frontage     2207 non-null   float64
#  4   Lot Area         2645 non-null   int64
#  5   Street           2645 non-null   object
#  6   Alley            184 non-null    object
#  7   Lot Shape        2645 non-null   object
#  8   Land Contour     2645 non-null   object
#  9   Utilities        2645 non-null   object
#  10  Lot Config       2645 non-null   object
#  11  Land Slope       2645 non-null   object
#  12  Neighborhood     2645 non-null   object
#  13  Condition 1      2645 non-null   object
#  14  Condition 2      2645 non-null   object
#  15  Bldg Type        2645 non-null   object
# ...

# %%
df.to_csv('project_data_outdone.csv',index=False)
