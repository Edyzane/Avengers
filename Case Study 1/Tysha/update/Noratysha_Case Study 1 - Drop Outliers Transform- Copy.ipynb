# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Data**

# %%
df = pd.read_csv('Ames_Housing_Data.csv')

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  SalePrice
# 0        0       5    2010        WD           Normal     215000
# 1        0       6    2010        WD           Normal     105000
# 2    12500       6    2010        WD           Normal     172000
# 3        0       4    2010        WD           Normal     244000
# 4        0       3    2010        WD           Normal     189900
#
# [5 rows x 81 columns]

# %%
df = df.drop(['PID','MS SubClass','Lot Frontage','Lot Area','BsmtFin SF 1','BsmtFin SF 2','Bsmt Unf SF','2nd Flr SF','Low Qual Fin SF','Bsmt Full Bath','Bsmt Half Bath','Half Bath','Bedroom AbvGr','Kitchen AbvGr','Enclosed Porch','Open Porch SF','3Ssn Porch','Screen Porch','Pool Area','Misc Val','Mo Sold','Yr Sold','Wood Deck SF','Overall Cond'],axis=1)

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal    215000
# 1            Normal    105000
# 2            Normal    172000
# 3            Normal    244000
# 4            Normal    189900
# ...             ...       ...
# 2925         Normal    142500
# 2926         Normal    131000
# 2927         Normal    132000
# 2928         Normal    170000
# 2929         Normal    188000
#
# [2930 rows x 57 columns]

# %%
X = df.drop('SalePrice',axis=1)
y = df['SalePrice']

# %% [markdown]
# **Removing Outliers**

# %% [markdown]
# Feature : Masonry veneer area in square feet

# %%
df[(df['Mas Vnr Area']>1500) & (df['SalePrice']<300000)].index
# Out:
# Int64Index([1849], dtype='int64')

# %%
df[(df['Mas Vnr Area']<10) & (df['SalePrice']>700000)].index
# Out:
# Int64Index([1760], dtype='int64')

# %%
df[(df['Mas Vnr Area']>1100) & (df['SalePrice']>550000)].index
# Out:
# Int64Index([1767, 2445], dtype='int64')

# %%
df[(df['Mas Vnr Area']>1000) & (df['SalePrice']>550000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 1767        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 2445        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 1767        Gtl      NoRidge        Norm  ...       832.0          TA
# 2445        Gtl      NoRidge        Norm  ...       807.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 1767          TA            Y      NaN    NaN          NaN       WD
# 2445          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 1767         Normal    755000
# 2445         Normal    625000
#
# [2 rows x 57 columns]

# %%
df[(df['Mas Vnr Area']>1400) & (df['SalePrice']<300000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 1849        FV   Pave  Pave       IR1          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 1849        Gtl      Somerst        Norm  ...       576.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 1849          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 1849         Normal    239000
#
# [1 rows x 57 columns]

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='Mas Vnr Area',whis=1.5,data=df)
# Out:
# <AxesSubplot:xlabel='Mas Vnr Area'>

# %%
plt.figure(figsize=(12,8))
sns.displot(data=df,x='SalePrice',kde=True)

# %%
plt.figure(figsize=(12,8))
sns.displot(data=df,x='SalePrice',kde=True)

# %%
df[(df['SalePrice']>700000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 1760        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1767        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 1760        Gtl      NoRidge        Norm  ...       813.0          TA
# 1767        Gtl      NoRidge        Norm  ...       832.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 1760          TA            Y       Ex  MnPrv          NaN       WD
# 1767          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 1760        Abnorml    745000
# 1767         Normal    755000
#
# [2 rows x 57 columns]

# %%
df['SalePrice'] = np.log10(df['SalePrice'])

# %%
plt.figure(figsize=(12,8))
sns.displot(data=df,x='SalePrice',kde=True)

# %%
sns.boxplot(x='SalePrice',whis=1.5,data=df)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
df[(df['SalePrice']<4.65)].index
# Out:
# Int64Index([181, 709, 726, 727, 1553, 1555, 1901, 2843, 2880], dtype='int64')

# %%
df.drop([181, 709, 726, 727, 1553, 1555, 1901, 2843, 2880],axis=0,inplace=True)

# %%
sns.boxplot(x='SalePrice',whis=1.5,data=df)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
df[(df['SalePrice']>5.8)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 1760        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1767        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 1760        Gtl      NoRidge        Norm  ...       813.0          TA
# 1767        Gtl      NoRidge        Norm  ...       832.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 1760          TA            Y       Ex  MnPrv          NaN       WD
# 1767          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 1760        Abnorml  5.872156
# 1767         Normal  5.877947
#
# [2 rows x 57 columns]

# %%
df.drop([1760, 1767],axis=0,inplace=True)

# %%
sns.kdeplot(x='SalePrice',data=df);

# %% [markdown]
# Feature : Total Basement in square feet

# %%
df[(df['Total Bsmt SF']>3000) & (df['SalePrice']<300000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 423         RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 444         RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 1498        RL   Pave   NaN       IR3          Bnk    AllPub     Corner
# 1772        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 2180        RL   Pave   NaN       IR1          Bnk    AllPub     Inside
# 2181        RL   Pave   NaN       IR1          Bnk    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 423         Gtl      NridgHt        Norm  ...       672.0          TA
# 444         Gtl      NridgHt        Norm  ...       880.0          TA
# 1498        Gtl      Edwards       Feedr  ...      1418.0          TA
# 1772        Gtl      NoRidge        Norm  ...       546.0          TA
# 2180        Gtl      Edwards        Norm  ...      1154.0          TA
# 2181        Gtl      Edwards        PosN  ...       884.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 423           TA            Y      NaN    NaN          NaN       WD
# 444           TA            Y      NaN    NaN          NaN       WD
# 1498          TA            Y       Gd    NaN          NaN       New
# 1772          TA            Y      NaN    NaN          NaN       WD
# 2180          TA            Y      NaN    NaN         Elev       New
# 2181          TA            Y      NaN    NaN          NaN       New
#
#      Sale Condition SalePrice
# 423          Normal  5.744293
# 444          Normal  5.453318
# 1498        Partial  5.204120
# 1772         Normal  5.633468
# 2180        Partial  5.264464
# 2181        Partial  5.266584
#
# [6 rows x 57 columns]

# %%
df[(df['Total Bsmt SF']>3000) & (df['SalePrice']<300000)].index
# Out:
# Int64Index([423, 444, 1498, 1772, 2180, 2181], dtype='int64')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Total Bsmt SF',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Bsmt SF', ylabel='SalePrice'>

# %%
df[(df['Total Bsmt SF']==0) & (df['SalePrice']>180000)]
# Out:
# Empty DataFrame
# Columns: [MS Zoning, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin Type 2, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, Gr Liv Area, Full Bath, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Pool QC, Fence, Misc Feature, Sale Type, Sale Condition, SalePrice]
# Index: []
#
# [0 rows x 57 columns]

# %%
df.drop([444,1498,2180,2181],axis=0,inplace=True)

# %%
df.drop([887,1497,2892],axis=0,inplace=True)

# %%
sns.displot(data=df,x='Total Bsmt SF',kde=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Total Bsmt SF',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Total Bsmt SF'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Total Bsmt SF',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Total Bsmt SF', ylabel='SalePrice'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2912 rows x 57 columns]

# %% [markdown]
# Feature : First Floor square feet

# %%
df[(df['1st Flr SF']>3000) & (df['SalePrice']>400000)].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.drop([1772],axis=0,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='1st Flr SF',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='1st Flr SF', ylabel='SalePrice'>

# %%
sns.displot(data=df,x='1st Flr SF',kde=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='1st Flr SF',whis=1.5)
# Out:
# <AxesSubplot:xlabel='1st Flr SF'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2911 rows x 57 columns]

# %% [markdown]
# Feature : Year garage was built

# %%
df[(df['Garage Yr Blt']>2200) & (df['SalePrice']<300000)].index
# Out:
# Int64Index([2260], dtype='int64')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Yr Blt',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Yr Blt', ylabel='SalePrice'>

# %%
df.drop([2260],axis=0,inplace=True)

# %%
df[(df['Garage Yr Blt']<1900)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 307    C (all)   Grvl   NaN       Reg          Lvl    AllPub     Corner
# 1554   C (all)   Pave   NaN       Reg          Lvl    AllPub     Corner
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 307         Gtl       IDOTRR        Norm  ...       330.0          TA
# 1554        Gtl       IDOTRR       Feedr  ...       185.0          Fa
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 307           TA            N      NaN    NaN          NaN       WD
# 1554          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 307          Alloca  4.700167
# 1554         Normal  4.949390
#
# [2 rows x 57 columns]

# %%
df.drop([307,1554],axis=0,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Yr Blt',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Yr Blt', ylabel='SalePrice'>

# %%
sns.displot(data=df,x='Garage Yr Blt',kde=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Garage Yr Blt',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Garage Yr Blt'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2908 rows x 57 columns]

# %% [markdown]
# Feature : Above grade (ground) living area square feet

# %%
sns.displot(data=df,x='Gr Liv Area',kde=True)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Gr Liv Area',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2908 rows x 57 columns]

# %% [markdown]
# Feature : Remodel date (same as construction date if no remodeling or additions)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Remod/Add',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Year Remod/Add', ylabel='SalePrice'>

# %%
df[(df['Year Remod/Add']<1975) & (df['SalePrice']<20000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 18          RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# ...        ...    ...   ...       ...          ...       ...        ...
# 2916        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2917        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2918        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2919        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2920        RM   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 18          Gtl      Gilbert        Norm  ...       400.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2916        Gtl      MeadowV        Norm  ...         0.0         NaN
# 2917        Gtl      MeadowV        Norm  ...       286.0          TA
# 2918        Gtl      MeadowV        Norm  ...         0.0         NaN
# 2919        Gtl      MeadowV        Norm  ...         0.0         NaN
# 2920        Gtl      MeadowV        Norm  ...       286.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 18            TA            Y      NaN    NaN          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2916         NaN            Y      NaN    NaN          NaN       WD
# 2917          TA            Y      NaN    NaN          NaN       WD
# 2918         NaN            Y      NaN  GdPrv          NaN       WD
# 2919         NaN            Y      NaN    NaN          NaN       WD
# 2920          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 18           Normal  5.149219
# ...             ...       ...
# 2916        Abnorml  4.963788
# 2917        Abnorml  4.942256
# 2918         Normal  4.900367
# 2919         Normal  4.956649
# 2920        Abnorml  4.851258
#
# [1005 rows x 57 columns]

# %%
df[(df['Year Remod/Add']<1970) & (df['SalePrice']>300000)].index
# Out:
# Int64Index([], dtype='int64')

# %%
df[(df['Year Remod/Add']<1985) & (df['SalePrice']>300000)].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.drop([956,1860],axis=0,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Remod/Add',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Year Remod/Add', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Year Remod/Add',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Year Remod/Add'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2906 rows x 57 columns]

# %% [markdown]
# Feature : Size of garage in square feet

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Area', ylabel='SalePrice'>

# %%
df[(df['Garage Area']==0) & (df['SalePrice']>200000)]
# Out:
# Empty DataFrame
# Columns: [MS Zoning, Street, Alley, Lot Shape, Land Contour, Utilities, Lot Config, Land Slope, Neighborhood, Condition 1, Condition 2, Bldg Type, House Style, Overall Qual, Year Built, Year Remod/Add, Roof Style, Roof Matl, Exterior 1st, Exterior 2nd, Mas Vnr Type, Mas Vnr Area, Exter Qual, Exter Cond, Foundation, Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin Type 2, Total Bsmt SF, Heating, Heating QC, Central Air, Electrical, 1st Flr SF, Gr Liv Area, Full Bath, Kitchen Qual, TotRms AbvGrd, Functional, Fireplaces, Fireplace Qu, Garage Type, Garage Yr Blt, Garage Finish, Garage Cars, Garage Area, Garage Qual, Garage Cond, Paved Drive, Pool QC, Fence, Misc Feature, Sale Type, Sale Condition, SalePrice]
# Index: []
#
# [0 rows x 57 columns]

# %%
df[(df['Garage Area']>1100) & (df['SalePrice']<200000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 366         RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 426         RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 746         RM   Pave   NaN       Reg          Lvl    AllPub     Inside
# 818         RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 862         RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 1027        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1052        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 1059        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 1258        RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
# 1425        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 1557   C (all)   Grvl   NaN       Reg          Low    AllPub     Inside
# 1637        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 1701        RL   Pave   NaN       IR2          Lvl    AllPub    CulDSac
# 1852        FV   Pave   NaN       IR1          Lvl    AllPub     Inside
# 1945        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2282        RL   Pave   NaN       Reg          Low    AllPub     Inside
# 2456        RL   Pave   NaN       IR2          Lvl    AllPub    CulDSac
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 366         Gtl      StoneBr        Norm  ...      1166.0          TA
# 426         Gtl      NridgHt        Norm  ...      1390.0          TA
# 746         Gtl      BrkSide        Norm  ...      1184.0          Fa
# 818         Gtl      CollgCr        Norm  ...      1138.0          TA
# 862         Gtl      CollgCr        Norm  ...      1231.0          TA
# 1027        Gtl       NWAmes        Norm  ...      1314.0          TA
# 1052        Gtl      NridgHt        PosN  ...      1220.0          TA
# 1059        Gtl      NridgHt        PosN  ...      1150.0          TA
# 1258        Gtl      OldTown        Norm  ...      1488.0          Fa
# 1425        Gtl      CollgCr        Norm  ...      1348.0          Gd
# 1557        Gtl       IDOTRR        Norm  ...      1248.0          TA
# 1637        Gtl      StoneBr        PosN  ...      1110.0          Gd
# 1701        Gtl      NridgHt        Norm  ...      1174.0          TA
# 1852        Gtl      Somerst        Norm  ...      1105.0          Gd
# 1945        Gtl        NAmes        Norm  ...      1200.0          TA
# 2282        Mod      Mitchel        Norm  ...      1356.0          TA
# 2456        Gtl      Somerst        RRAn  ...      1134.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 366           TA            Y      NaN    NaN          NaN       New
# 426           TA            Y      NaN    NaN          NaN       New
# 746           TA            P      NaN    NaN          NaN       WD
# 818           TA            Y      NaN    NaN          NaN       New
# 862           TA            Y      NaN    NaN          NaN       WD
# 1027          Gd            Y      NaN  MnPrv          NaN       WD
# 1052          TA            Y      NaN    NaN          NaN       New
# 1059          TA            Y      NaN    NaN          NaN       WD
# 1258          TA            N      NaN   GdWo          NaN       WD
# 1425          TA            Y      NaN    NaN          NaN       WD
# 1557          TA            Y      NaN    NaN         Shed     ConLD
# 1637          TA            Y      NaN    NaN          NaN       New
# 1701          TA            Y      NaN    NaN          NaN       New
# 1852          TA            Y      NaN    NaN          NaN       WD
# 1945          TA            Y      NaN    NaN          NaN       WD
# 2282          TA            Y      NaN    NaN          NaN       WD
# 2456          TA            Y      NaN    NaN          NaN       New
#
#      Sale Condition SalePrice
# 366         Partial  5.700563
# 426         Partial  5.403623
# 746          Normal  5.102091
# 818         Partial  5.509555
# 862          Normal  5.397940
# 1027         Normal  5.466126
# 1052        Partial  5.585461
# 1059         Normal  5.662758
# 1258         Normal  5.143015
# 1425        Abnorml  5.676694
# 1557         Normal  4.908485
# 1637        Partial  5.772019
# 1701        Partial  5.699028
# 1852         Normal  5.494850
# 1945         Family  5.479431
# 2282         Normal  5.225309
# 2456        Partial  5.626340
#
# [17 rows x 57 columns]

# %%
df.drop([746,1258,1557,2282,1407],axis=0,inplace=True)

# %%
df[(df['Garage Area']>1300)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 426         RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 1027        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1425        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 426         Gtl      NridgHt        Norm  ...      1390.0          TA
# 1027        Gtl       NWAmes        Norm  ...      1314.0          TA
# 1425        Gtl      CollgCr        Norm  ...      1348.0          Gd
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 426           TA            Y      NaN    NaN          NaN       New
# 1027          Gd            Y      NaN  MnPrv          NaN       WD
# 1425          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 426         Partial  5.403623
# 1027         Normal  5.466126
# 1425        Abnorml  5.676694
#
# [3 rows x 57 columns]

# %%
df.drop([426,1027,1425],axis=0,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Area', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Garage Area',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Garage Area'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2898 rows x 57 columns]

# %% [markdown]
# Feature : Size of garage in car capacity

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Garage Cars',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Garage Cars', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Garage Cars',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Garage Cars'>

# %%
df[(df['Garage Cars']>3.5)].index
# Out:
# Int64Index([246, 669, 716, 815, 816, 817, 1059, 1588, 1589, 1668, 2278, 2749,
#             2904],
#            dtype='int64')

# %%
df.drop([246, 669, 716, 815, 816, 817, 1059, 1588, 1589, 1668, 2278,2749, 2904],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Garage Cars',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Garage Cars'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2885 rows x 57 columns]

# %% [markdown]
# Feature : Fireplaces

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Fireplaces',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Fireplaces', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Fireplaces',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
df[(df['Fireplaces']>2.5)].index
# Out:
# Int64Index([343, 421, 626, 785, 1924, 2223, 2395, 2498, 2500, 2518, 2590,
#             2869],
#            dtype='int64')

# %%
df.drop([343, 421, 626, 785, 1924, 2223, 2395, 2498, 2500, 2518, 2590,2869],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Fireplaces',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Fireplaces'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Fireplaces',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Fireplaces', ylabel='SalePrice'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2873 rows x 57 columns]

# %% [markdown]
# Feature : Total rooms above grade (does not include bathrooms)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='TotRms AbvGrd',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='TotRms AbvGrd', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='TotRms AbvGrd',whis=1.5)
# Out:
# <AxesSubplot:xlabel='TotRms AbvGrd'>

# %%
df[(df['TotRms AbvGrd']>12)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 925         RL   Pave   NaN       IR1          HLS    AllPub     Corner
# 2194        RH   Pave  Pave       Reg          Bnk    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 925         Gtl      Crawfor        Norm  ...       400.0          TA
# 2194        Gtl        SWISU       Feedr  ...         0.0         NaN
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 925           TA            Y      NaN    NaN          NaN       WD
# 2194         NaN            N      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 925          Normal  5.311754
# 2194        Abnorml  5.301030
#
# [2 rows x 57 columns]

# %%
df.drop([925,2194],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='TotRms AbvGrd',whis=1.5)
# Out:
# <AxesSubplot:xlabel='TotRms AbvGrd'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2871 rows x 57 columns]

# %% [markdown]
# Feature : Rates the overall material and finish of the house

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Overall Qual', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Overall Qual',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Overall Qual'>

# %%
df[(df['Overall Qual']<2)].index
# Out:
# Int64Index([765, 2903], dtype='int64')

# %%
df.drop([765, 2903],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Overall Qual',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Overall Qual'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2869 rows x 57 columns]

# %% [markdown]
# Feature : Original construction date

# %%
df[(df['Year Built']>2000) & (df['SalePrice']<100000)]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 6           RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 15          RL   Pave   NaN       IR2          HLS    AllPub    CulDSac
# 17          RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 36          RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# 37          RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2899        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2900        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 2901        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2902        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2907        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 6           Gtl      StoneBr        Norm  ...       582.0          TA
# 15          Mod      StoneBr        Norm  ...       841.0          TA
# 17          Gtl      StoneBr        Norm  ...       834.0          TA
# 36          Gtl      NridgHt        Norm  ...       751.0          TA
# 37          Gtl      NridgHt        Norm  ...       772.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2899        Gtl       Timber        Norm  ...       765.0          TA
# 2900        Gtl       Timber        Norm  ...       714.0          TA
# 2901        Gtl       Timber        Norm  ...       880.0          TA
# 2902        Gtl       Timber        Norm  ...       682.0          TA
# 2907        Gtl      Mitchel        Norm  ...         0.0         NaN
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 6             TA            Y      NaN    NaN          NaN       WD
# 15            TA            Y      NaN    NaN          NaN       WD
# 17            TA            Y      NaN    NaN          NaN       New
# 36            TA            Y      NaN    NaN          NaN       New
# 37            TA            Y      NaN    NaN          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2899          TA            Y      NaN    NaN          NaN       WD
# 2900          TA            Y      NaN    NaN          NaN       New
# 2901          TA            Y      NaN    NaN          NaN       New
# 2902          TA            Y      NaN    NaN          NaN       New
# 2907         NaN            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 6            Normal  5.329398
# 15           Normal  5.730782
# 17          Partial  5.595972
# 36          Partial  5.575375
# 37           Normal  5.485721
# ...             ...       ...
# 2899         Normal  5.494850
# 2900        Partial  5.505150
# 2901        Partial  5.568084
# 2902        Partial  5.556182
# 2907        Abnorml  4.926857
#
# [724 rows x 57 columns]

# %%
df.drop([185,1306,1320,2666,2907],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Year Built',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Year Built'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Year Built',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Year Built', ylabel='SalePrice'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2864 rows x 57 columns]

# %% [markdown]
# Feature : Full bathrooms above grade

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Full Bath',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Full Bath', ylabel='SalePrice'>

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Full Bath',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Full Bath'>

# %%
df[(df['Full Bath']==4)]
# Out:
#     MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 336        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#     Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 336        Gtl      Mitchel        Norm  ...       616.0          TA
#
#     Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 336          Fa            Y      NaN    NaN         Shed       WD
#
#     Sale Condition SalePrice
# 336         Normal  5.201397
#
# [1 rows x 57 columns]

# %%
df.drop([1063,336],axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-f46b353c64b9> in <module>
# ----> 1 df.drop([1063,336],axis=0,inplace=True)
#
# ~\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4167             level=level,
#    4168             inplace=inplace,
# -> 4169             errors=errors,
#    4170         )
#    4171
#
# ~\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# ~\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3916                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3917             else:
# -> 3918                 new_axis = axis.drop(labels, errors=errors)
#    3919             result = self.reindex(**{axis_name: new_axis})
#    3920
#
# ~\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5276         if mask.any():
#    5277             if errors != "ignore":
# -> 5278                 raise KeyError(f"{labels[mask]} not found in axis")
#    5279             indexer = indexer[~mask]
#    5280         return self.delete(indexer)
#
# KeyError: '[1063  336] not found in axis'

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='Full Bath',whis=1.5)
# Out:
# <AxesSubplot:xlabel='Full Bath'>

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2862 rows x 57 columns]

# %% [markdown]
# **Removing Sale Price more than 550000**

# %%
df[df['SalePrice']>480000].index
# Out:
# Int64Index([], dtype='int64')

# %%
df.drop([15,44,46,366,422,423,432,433,456, 1637, 1691,1701, 2330, 2332, 2334, 2450],axis=0,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=df,x='SalePrice',whis=1.5)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
sns.displot(data=df,x='SalePrice',kde=True)

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2925        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2926        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2927        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2928        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2929        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0           Gtl        NAmes        Norm  ...       528.0          TA
# 1           Gtl        NAmes       Feedr  ...       730.0          TA
# 2           Gtl        NAmes        Norm  ...       312.0          TA
# 3           Gtl        NAmes        Norm  ...       522.0          TA
# 4           Gtl      Gilbert        Norm  ...       482.0          TA
# ...         ...          ...         ...  ...         ...         ...
# 2925        Gtl      Mitchel        Norm  ...       588.0          TA
# 2926        Mod      Mitchel        Norm  ...       484.0          TA
# 2927        Gtl      Mitchel        Norm  ...         0.0         NaN
# 2928        Mod      Mitchel        Norm  ...       418.0          TA
# 2929        Mod      Mitchel        Norm  ...       650.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0             TA            P      NaN    NaN          NaN       WD
# 1             TA            Y      NaN  MnPrv          NaN       WD
# 2             TA            Y      NaN    NaN         Gar2       WD
# 3             TA            Y      NaN    NaN          NaN       WD
# 4             TA            Y      NaN  MnPrv          NaN       WD
# ...          ...          ...      ...    ...          ...       ...
# 2925          TA            Y      NaN  GdPrv          NaN       WD
# 2926          TA            Y      NaN  MnPrv          NaN       WD
# 2927         NaN            Y      NaN  MnPrv         Shed       WD
# 2928          TA            Y      NaN    NaN          NaN       WD
# 2929          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 0            Normal  5.332438
# 1            Normal  5.021189
# 2            Normal  5.235528
# 3            Normal  5.387390
# 4            Normal  5.278525
# ...             ...       ...
# 2925         Normal  5.153815
# 2926         Normal  5.117271
# 2927         Normal  5.120574
# 2928         Normal  5.230449
# 2929         Normal  5.274158
#
# [2846 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2846 entries, 0 to 2929
# Data columns (total 57 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MS Zoning       2846 non-null   object
#  1   Street          2846 non-null   object
#  2   Alley           192 non-null    object
#  3   Lot Shape       2846 non-null   object
#  4   Land Contour    2846 non-null   object
#  5   Utilities       2846 non-null   object
#  6   Lot Config      2846 non-null   object
#  7   Land Slope      2846 non-null   object
#  8   Neighborhood    2846 non-null   object
#  9   Condition 1     2846 non-null   object
#  10  Condition 2     2846 non-null   object
#  11  Bldg Type       2846 non-null   object
#  12  House Style     2846 non-null   object
#  13  Overall Qual    2846 non-null   int64
#  14  Year Built      2846 non-null   int64
#  15  Year Remod/Add  2846 non-null   int64
#  16  Roof Style      2846 non-null   object
#  17  Roof Matl       2846 non-null   object
#  18  Exterior 1st    2846 non-null   object
#  19  Exterior 2nd    2846 non-null   object
#  20  Mas Vnr Type    2824 non-null   object
#  21  Mas Vnr Area    2824 non-null   float64
#  22  Exter Qual      2846 non-null   object
#  23  Exter Cond      2846 non-null   object
#  24  Foundation      2846 non-null   object
#  25  Bsmt Qual       2773 non-null   object
#  26  Bsmt Cond       2773 non-null   object
#  27  Bsmt Exposure   2770 non-null   object
#  28  BsmtFin Type 1  2773 non-null   object
#  29  BsmtFin Type 2  2773 non-null   object
#  30  Total Bsmt SF   2845 non-null   float64
#  31  Heating         2846 non-null   object
#  32  Heating QC      2846 non-null   object
#  33  Central Air     2846 non-null   object
#  34  Electrical      2845 non-null   object
#  35  1st Flr SF      2846 non-null   int64
#  36  Gr Liv Area     2846 non-null   int64
#  37  Full Bath       2846 non-null   int64
#  38  Kitchen Qual    2846 non-null   object
#  39  TotRms AbvGrd   2846 non-null   int64
#  40  Functional      2846 non-null   object
#  41  Fireplaces      2846 non-null   int64
#  42  Fireplace Qu    1450 non-null   object
#  43  Garage Type     2697 non-null   object
#  44  Garage Yr Blt   2695 non-null   float64
#  45  Garage Finish   2695 non-null   object
#  46  Garage Cars     2845 non-null   float64
#  47  Garage Area     2845 non-null   float64
#  48  Garage Qual     2695 non-null   object
#  49  Garage Cond     2695 non-null   object
#  50  Paved Drive     2846 non-null   object
#  51  Pool QC         8 non-null      object
#  52  Fence           560 non-null    object
#  53  Misc Feature    103 non-null    object
#  54  Sale Type       2846 non-null   object
#  55  Sale Condition  2846 non-null   object
#  56  SalePrice       2846 non-null   float64
# dtypes: float64(6), int64(8), object(43)
# memory usage: 1.3+ MB

# %%
df.to_csv(r'C:\Users\Acer\Ames Housing Data No Outlier Edited.csv',index=False)
