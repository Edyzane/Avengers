# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Ames Housing Data No Outlier.csv')

# %%
df.head()
# Out:
#   MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1        RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2        RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3        RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4        RL   Pave   NaN       IR1          Lvl    AllPub     Inside
#
#   Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 0        Gtl        NAmes        Norm  ...       528.0          TA
# 1        Gtl        NAmes       Feedr  ...       730.0          TA
# 2        Gtl        NAmes        Norm  ...       312.0          TA
# 3        Gtl        NAmes        Norm  ...       522.0          TA
# 4        Gtl      Gilbert        Norm  ...       482.0          TA
#
#   Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 0          TA            P      NaN    NaN          NaN       WD
# ...

# %%
X = df.drop('SalePrice',axis=1)
y = df['SalePrice']

# %%
df
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 1           RH   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2           RL   Pave   NaN       IR1          Lvl    AllPub     Corner
# 3           RL   Pave   NaN       Reg          Lvl    AllPub     Corner
# 4           RL   Pave   NaN       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2849        RL   Pave   NaN       IR1          Lvl    AllPub    CulDSac
# 2850        RL   Pave   NaN       IR1          Low    AllPub     Inside
# 2851        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2852        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
# 2853        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# ...

# %%
df.isnull().sum().sort_values()
# Out:
# MS Zoning            0
# Exter Cond           0
# Foundation           0
# Sale Condition       0
# Heating              0
# Heating QC           0
# Central Air          0
# 1st Flr SF           0
# Gr Liv Area          0
# Full Bath            0
# Kitchen Qual         0
# TotRms AbvGrd        0
# Functional           0
# Fireplaces           0
# Paved Drive          0
# Sale Type            0
# Exter Qual           0
# Exterior 2nd         0
# SalePrice            0
# Roof Matl            0
# Street               0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Exterior 1st         0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Land Slope           0
# Overall Qual         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Electrical           1
# Garage Area          1
# Garage Cars          1
# Total Bsmt SF        1
# ...

# %%
mis_value = df.isnull().sum().sort_values(ascending=False)/len(df)

# %%
mis_value = mis_value[mis_value>0].sort_values()

# %%
mis_value
# Out:
# Electrical        0.000350
# Garage Cars       0.000350
# Total Bsmt SF     0.000350
# Garage Area       0.000350
# Mas Vnr Type      0.007708
# Mas Vnr Area      0.007708
# BsmtFin Type 2    0.026279
# BsmtFin Type 1    0.026279
# Bsmt Qual         0.026279
# Bsmt Cond         0.026279
# Bsmt Exposure     0.027330
# Garage Type       0.053259
# Garage Finish     0.053959
# Garage Qual       0.053959
# Garage Cond       0.053959
# Garage Yr Blt     0.053959
# Fireplace Qu      0.491591
# Fence             0.802733
# Alley             0.932376
# Misc Feature      0.963910
# Pool QC           0.997197
# dtype: float64

# %%
def missing_data(df):
    mis_value = df.isnull().sum().sort_values(ascending=False)/len(df)
    mis_value = mis_value[mis_value>0].sort_values()
    return mis_value

# %%
mis_value = missing_data(df)

# %%
mis_value
# Out:
# Electrical        0.000350
# Garage Cars       0.000350
# Total Bsmt SF     0.000350
# Garage Area       0.000350
# Mas Vnr Type      0.007708
# Mas Vnr Area      0.007708
# BsmtFin Type 2    0.026279
# BsmtFin Type 1    0.026279
# Bsmt Qual         0.026279
# Bsmt Cond         0.026279
# Bsmt Exposure     0.027330
# Garage Type       0.053259
# Garage Finish     0.053959
# Garage Qual       0.053959
# Garage Cond       0.053959
# Garage Yr Blt     0.053959
# Fireplace Qu      0.491591
# Fence             0.802733
# Alley             0.932376
# Misc Feature      0.963910
# Pool QC           0.997197
# dtype: float64

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %%
df[df['Electrical'].isnull()]
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 1537        RL   Pave   NaN       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Area Garage Qual  \
# 1537        Gtl       Timber        Norm  ...       400.0          TA
#
#      Garage Cond  Paved Drive  Pool QC  Fence Misc Feature Sale Type  \
# 1537          TA            Y      NaN    NaN          NaN       WD
#
#      Sale Condition SalePrice
# 1537         Normal    167500
#
# [1 rows x 57 columns]

# %%
#Seperate Numerical And Categorical Variables
num = df.columns[df.dtypes != 'object']
cat = df.columns[df.dtypes == 'object']

print(num)
print(cat)
# Out:
# Index(['Overall Qual', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area',
#        'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Full Bath',
#        'TotRms AbvGrd', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars',
#        'Garage Area', 'SalePrice'],
#       dtype='object')
# Index(['MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour',
#        'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl',
#        'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
#        'Sale Type', 'Sale Condition'],
# ...

# %% [markdown]
# **Drop Features that has up to 50% of missing values**

# %%
df = df.drop(['Pool QC','Misc Feature','Alley','Fence'],axis=1)

# %%
df
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1           RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2849        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2850        RL   Pave       IR1          Low    AllPub     Inside        Mod
# 2851        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2852        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
# 2853        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
#
# ...

# %%
mis_value = missing_data(df)

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %% [markdown]
# **Drop row that have only 1 missing value**

# %%
df = df.dropna(subset = ['Electrical','Garage Area','Garage Cars','Total Bsmt SF'],axis=0)

# %%
df
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1           RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2849        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2850        RL   Pave       IR1          Low    AllPub     Inside        Mod
# 2851        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2852        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
# 2853        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
#
# ...

# %%
mis_value = missing_data(df)

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %% [markdown]
# **Fill Missing Value in Mas Vnr Features**

# %%
Mas_str = ['Mas Vnr Type']
df[Mas_str] = df[Mas_str].fillna("None")
# Out:
# C:\Users\Acer\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
Mas_num = ['Mas Vnr Area']
df[Mas_num] = df[Mas_num].fillna(0)

# %%
mis_value = missing_data(df)

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %% [markdown]
# **Fill Missing Value in Fireplace Qu**

# %%
df['Fireplace Qu'] = df['Fireplace Qu'].fillna("NA")
# Out:
# C:\Users\Acer\anaconda3\envs\NSSDC\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mis_value = missing_data(df)

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %% [markdown]
# **Fill Missing Value in Basements Features**

# %%
bsmt_str = ['Bsmt Qual','Bsmt Cond','Bsmt Exposure','BsmtFin Type 1','BsmtFin Type 2']
df[bsmt_str]=df[bsmt_str].fillna("None")
# Out:
# C:\Users\Acer\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
mis_value = missing_data(df)

# %%
sns.barplot(x=mis_value.index,y=mis_value)
plt.xticks(rotation=90);

# %% [markdown]
# **Fill Missing Value in Garage Features**

# %%
garage_str = ['Garage Type','Garage Finish','Garage Qual','Garage Cond']
df[garage_str] = df[garage_str].fillna('None')
# Out:
# C:\Users\Acer\anaconda3\envs\NSSDC\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
mis_value = missing_data(df)

# %%
df[df['Garage Yr Blt'].isnull()]
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 26          RL   Pave       Reg          Lvl    AllPub        FR2        Gtl
# 116         RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 122         RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 126         RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 127         RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2837        RM   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2840        RM   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2842        RM   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2843        RM   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2851        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
#
# ...

# %%
df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(df['Year Built'])
# Out:
# C:\Users\Acer\anaconda3\envs\NSSDC\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mis_value = missing_data(df)

# %%
mis_value
# Out:
# Series([], dtype: float64)

# %%
df
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1           RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2849        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2850        RL   Pave       IR1          Low    AllPub     Inside        Mod
# 2851        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2852        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
# 2853        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2851 entries, 0 to 2853
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MS Zoning       2851 non-null   object
#  1   Street          2851 non-null   object
#  2   Lot Shape       2851 non-null   object
#  3   Land Contour    2851 non-null   object
#  4   Utilities       2851 non-null   object
#  5   Lot Config      2851 non-null   object
#  6   Land Slope      2851 non-null   object
#  7   Neighborhood    2851 non-null   object
#  8   Condition 1     2851 non-null   object
#  9   Condition 2     2851 non-null   object
#  10  Bldg Type       2851 non-null   object
#  11  House Style     2851 non-null   object
#  12  Overall Qual    2851 non-null   int64
#  13  Year Built      2851 non-null   int64
#  14  Year Remod/Add  2851 non-null   int64
#  15  Roof Style      2851 non-null   object
#  16  Roof Matl       2851 non-null   object
# ...

# %%
df.to_csv(r'C:\Users\Acer\Ames Housing Data No Missing Values.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2851 entries, 0 to 2853
# Data columns (total 53 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MS Zoning       2851 non-null   object
#  1   Street          2851 non-null   object
#  2   Lot Shape       2851 non-null   object
#  3   Land Contour    2851 non-null   object
#  4   Utilities       2851 non-null   object
#  5   Lot Config      2851 non-null   object
#  6   Land Slope      2851 non-null   object
#  7   Neighborhood    2851 non-null   object
#  8   Condition 1     2851 non-null   object
#  9   Condition 2     2851 non-null   object
#  10  Bldg Type       2851 non-null   object
#  11  House Style     2851 non-null   object
#  12  Overall Qual    2851 non-null   int64
#  13  Year Built      2851 non-null   int64
#  14  Year Remod/Add  2851 non-null   int64
#  15  Roof Style      2851 non-null   object
#  16  Roof Matl       2851 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# MS Zoning         0
# Street            0
# Lot Shape         0
# Land Contour      0
# Utilities         0
# Lot Config        0
# Land Slope        0
# Neighborhood      0
# Condition 1       0
# Condition 2       0
# Bldg Type         0
# House Style       0
# Overall Qual      0
# Year Built        0
# Year Remod/Add    0
# Roof Style        0
# Roof Matl         0
# Exterior 1st      0
# Exterior 2nd      0
# Mas Vnr Type      0
# Mas Vnr Area      0
# Exter Qual        0
# Exter Cond        0
# Foundation        0
# Bsmt Qual         0
# Bsmt Cond         0
# Bsmt Exposure     0
# BsmtFin Type 1    0
# BsmtFin Type 2    0
# Total Bsmt SF     0
# Heating           0
# Heating QC        0
# Central Air       0
# Electrical        0
# 1st Flr SF        0
# Gr Liv Area       0
# Full Bath         0
# Kitchen Qual      0
# TotRms AbvGrd     0
# Functional        0
# Fireplaces        0
# Fireplace Qu      0
# Garage Type       0
# Garage Yr Blt     0
# Garage Finish     0
# ...
